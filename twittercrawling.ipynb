# %%
# 해시태그 검색(1개)
def twitterfunc(searchtext):
    from selenium import webdriver
    import time
    import re
    import numpy as np
    import pandas as pd
    from urllib import parse
    from bs4 import BeautifulSoup

    para = parse.quote(searchtext)     # 한글 인코딩

    driver = webdriver.Chrome('C:/work/chromedriver')
    driver.get('https://twitter.com/')
    time.sleep(3)
    driver.find_element_by_css_selector("div.css-901oao.r-1awozwy.r-13gxpu9.r-6koalj.r-18u37iz.r-16y2uox.r-1qd0xha.r-a023e6.r-b88u0q.r-1777fci.r-eljoum.r-dnmrzs.r-bcqeeo.r-q4m81j.r-qvutc0").click()
    email = 'yuikl3521@naver.com'   ### 계정 정보 수정 필요
    input_id = driver.find_elements_by_css_selector("input[name='session[username_or_email]']")[0]
    input_id.clear()
    input_id.send_keys(email)

    password = 'bjhy8725' ### 비번 정보 수정 필요
    input_pw = driver.find_elements_by_css_selector("input[name='session[password]']")[0]
    input_pw.clear()
    input_pw.send_keys(password)
    input_pw.submit()
    time.sleep(3)

    driver.get('https://twitter.com/search?q=%23{}}&f=live'.format(para))

    n = 0
    
    numls=[]
    tagls = []
    id = ""
    while(n<200):
        time.sleep(5)
        for k in range(10 * n + 1, 10 * n + 11):
            print(k)
                
            try:
                text = driver.find_elements_by_css_selector("div.css-901oao.r-18jsvk2.r-1qd0xha.r-a023e6.r-16dba41.r-ad9z0x.r-bcqeeo.r-bnwqim.r-qvutc0")[1].text
                tags = re.findall(r'#[^\s#,\\]+', text) 
                t = []
                s = []
                for i in text:
                    text = i.text
                    tags = re.findall(r'#[^\s#,\\]+', text) 
                    t.append(tags)
                print(sum(t, []))    
                tagls.append(sum(t, []))
                numls.append(k)
            except:
                t = []
                print(sum(t, []))    
                tagls.append(sum(t, []))
                numls.append(k)
                
        time.sleep(5)
        last_height = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(10)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(10)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break

            else:
                last_height = new_height
                
                

        
        n += 1
        print()
    df = pd.DataFrame({'scrollnum':numls, 'tag':tagls})
    print(df)
    df.to_excel('C:\work\{}.xlsx'.format(searchtext))
    driver.quit()

# %%
# 해시태그 검색(2개)
def twitterfunc(searchtext1,searchtext2):
    from selenium import webdriver
    import time
    import re
    import numpy as np
    import pandas as pd
    from urllib import parse
    from bs4 import BeautifulSoup

    para1 = parse.quote(searchtext1)
    para2 = parse.quote(searchtext2)

    driver = webdriver.Chrome('C:/work/chromedriver')
    driver.get('https://twitter.com/')
    time.sleep(3)
    driver.find_element_by_css_selector("div.css-901oao.r-1awozwy.r-13gxpu9.r-6koalj.r-18u37iz.r-16y2uox.r-1qd0xha.r-a023e6.r-b88u0q.r-1777fci.r-eljoum.r-dnmrzs.r-bcqeeo.r-q4m81j.r-qvutc0").click()
    email = 'yuikl3521@naver.com'   ### 계정 정보 수정 필요
    input_id = driver.find_elements_by_css_selector("input[name='session[username_or_email]']")[0]
    time.sleep(1)
    input_id.clear()
    input_id.send_keys(email)

    password = 'bjhy8725' ### 비번 정보 수정 필요
    input_pw = driver.find_elements_by_css_selector("input[name='session[password]']")[0]
    time.sleep(1)
    input_pw.clear()
    input_pw.send_keys(password)
    input_pw.submit()
    time.sleep(4)

    driver.get('https://twitter.com/search?q=%23{}%20%23{}&f=live'.format(para1, para2))

    tagls = []
    numls = []
    n = 0
    while(n < 300):
        time.sleep(3)
        for k in range(9):
            try:
                text = driver.find_elements_by_css_selector("div.css-901oao.r-18jsvk2.r-1qd0xha.r-a023e6.r-16dba41.r-ad9z0x.r-bcqeeo.r-bnwqim.r-qvutc0")[k].text
                
            except:
                text = ""
                
            print(k)
            tags = re.findall(r'#[^\s#,\\]+', text) 
            tagls.append(tags)    
            numls.append(9 * n + k)
    #     print(tagls)
        time.sleep(3)
        last_height = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(3)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(3)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break

            else:
                last_height = new_height
        n += 1
        print()
    df = pd.DataFrame({'scrollnum':numls, 'tag':tagls})
    print(df)
    df.to_excel('C:\\work\\twitterdata\\{}.xlsx'.format(searchtext1 + '_' + searchtext2))
    driver.quit()
